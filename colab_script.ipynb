# %%
# !pip install playwright
# !playwright install chromium
# !playwright install-deps
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 11.6 MB/s eta 0:00:00
# ...
# (node:642) [DEP0169] DeprecationWarning: `url.parse()` behavior is not standardized and prone to errors that have security implications. Use the WHATWG URL API instead. CVEs are not issued for `url.parse()` vulnerabilities.
# (Use `node --trace-deprecation ...` to show where the warning was created)
# ...

# %%
import json

# Load the cookies you exported from your browser
with open('cookies.json', 'r') as f:
    browser_cookies = json.load(f)

# Convert to Playwright format
playwright_cookies = []
for c in browser_cookies:
    playwright_cookies.append({
        "name": c["name"],
        "value": c["value"],
        "domain": ".bing.com",
        "path": c["path"],
        "expires": c.get("expirationDate", -1),
        "httpOnly": c.get("httpOnly", False),
        "secure": c.get("secure", True),
        "sameSite": "Lax"
    })

storage_state = {"cookies": playwright_cookies, "origins": []}

with open('auth.json', 'w') as f:
    json.dump(storage_state, f)

print("✅ auth.json created! Download it from the folder icon on the left.")
# Out:
# ✅ auth.json created! Download it from the folder icon on the left.

# %% [markdown]
# install cookie editor in browser, run an search, export it as cookies.json upload hear and run to get auth.json. uploaded it in github 15-30 days once.
